# %%
import pandas as pd
import numpy as np

# %%
dates=pd.date_range('20240601',periods=6)
df=pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2024-06-01  0.701886 -1.430162  2.090013 -1.557625
# 2024-06-02 -1.071953  0.859555  0.633622 -1.842568
# 2024-06-03 -0.471158 -0.545979 -1.362554 -1.192127
# 2024-06-04 -1.751874 -0.269097 -1.163412  1.002821
# 2024-06-05 -0.067038  0.227775 -0.329943  0.971645
# 2024-06-06 -0.352371 -0.410662 -1.731466 -1.187982

# %%
s=pd.Series([1,2,4,np.nan,6,8],index=dates)
s
# Out:
# 2024-06-01    1.0
# 2024-06-02    2.0
# 2024-06-03    4.0
# 2024-06-04    NaN
# 2024-06-05    6.0
# 2024-06-06    8.0
# Freq: D, dtype: float64

# %%
s=pd.Series([1,2,4,np.nan,6,8],index=dates).shift(2)
s
# Out:
# 2024-06-01    NaN
# 2024-06-02    NaN
# 2024-06-03    1.0
# 2024-06-04    2.0
# 2024-06-05    4.0
# 2024-06-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2024-06-01       NaN       NaN       NaN       NaN
# 2024-06-02       NaN       NaN       NaN       NaN
# 2024-06-03 -1.471158 -1.545979 -2.362554 -2.192127
# 2024-06-04 -3.751874 -2.269097 -3.163412 -0.997179
# 2024-06-05 -4.067038 -3.772225 -4.329943 -3.028355
# 2024-06-06       NaN       NaN       NaN       NaN

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts.plot()
# Out:
# <Axes: >

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >
