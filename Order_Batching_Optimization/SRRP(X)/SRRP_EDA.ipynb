# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 9999

# %%
path='./SRRP-instances/Small instances/i25-t03-01/'
file_list=os.listdir(path)
df_name=['demand','distance','inventory','max_capacity','meta_info','replenishment']
for f in range(len(file_list)):
    try:
        globals()[df_name[f]]=pd.read_csv(path+file_list[f])
    except:
        globals()[df_name[f]]=np.load(path+file_list[f])

# %%
import matplotlib.pyplot as plt 

plt.pcolor(distance)
