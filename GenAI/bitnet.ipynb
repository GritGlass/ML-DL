# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "microsoft/bitnet-b1.58-2B-4T"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16
)

# Apply the chat template
messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "How are you?"},
]
prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
chat_input = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generate response
chat_outputs = model.generate(**chat_input, max_new_tokens=50)
response = tokenizer.decode(chat_outputs[0][chat_input['input_ids'].shape[-1]:], skip_special_tokens=True) # Decode only the response part
print("\nAssistant Response:", response)
# Out:
# You don't have a GPU available to load the model, the inference will be slow because of weight unpacking
# model.safetensors:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hyr69\.cache\huggingface\hub\models--microsoft--bitnet-b1.58-2B-4T. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# InductorError                             Traceback (most recent call last)
# Cell In[1], line 8
#       6 # Load tokenizer and model
#       7 tokenizer = AutoTokenizer.from_pretrained(model_id)
# ----> 8 model = AutoModelForCausalLM.from_pretrained(
#       9     model_id,
#      10     torch_dtype=torch.bfloat16
#      11 )
#      13 # Apply the chat template
#      14 messages = [
#      15     {"role": "system", "content": "You are a helpful AI assistant."},
#      16     {"role": "user", "content": "How are you?"},
#      17 ]
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\models\auto\auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\modeling_utils.py:280, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     278 old_dtype = torch.get_default_dtype()
#     279 try:
# --> 280     return func(*args, **kwargs)
#     281 finally:
#     282     torch.set_default_dtype(old_dtype)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\modeling_utils.py:4513, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4503     if dtype_orig is not None:
#    4504         torch.set_default_dtype(dtype_orig)
#    4506     (
#    4507         model,
#    4508         missing_keys,
#    4509         unexpected_keys,
#    4510         mismatched_keys,
#    4511         offload_index,
#    4512         error_msgs,
# -> 4513     ) = cls._load_pretrained_model(
#    4514         model,
#    4515         state_dict,
#    4516         checkpoint_files,
#    4517         pretrained_model_name_or_path,
#    4518         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4519         sharded_metadata=sharded_metadata,
#    4520         device_map=device_map,
#    4521         disk_offload_folder=offload_folder,
#    4522         offload_state_dict=offload_state_dict,
#    4523         dtype=torch_dtype,
#    4524         hf_quantizer=hf_quantizer,
#    4525         keep_in_fp32_regex=keep_in_fp32_regex,
#    4526         device_mesh=device_mesh,
#    4527         key_mapping=key_mapping,
#    4528         weights_only=weights_only,
#    4529     )
#    4531 # record tp degree the model sharded to
#    4532 model._tp_size = tp_size
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\modeling_utils.py:4952, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    4950 # Skip it with fsdp on ranks other than 0
#    4951 elif not (is_fsdp_enabled() and not is_local_dist_rank_0() and not is_quantized):
# -> 4952     disk_offload_index, cpu_offload_index = _load_state_dict_into_meta_model(
#    4953         model_to_load,
#    4954         state_dict,
#    4955         shard_file,
#    4956         expected_keys,
#    4957         reverse_key_renaming_mapping,
#    4958         device_map=device_map,
#    4959         disk_offload_folder=disk_offload_folder,
#    4960         disk_offload_index=disk_offload_index,
#    4961         cpu_offload_folder=cpu_offload_folder,
#    4962         cpu_offload_index=cpu_offload_index,
#    4963         hf_quantizer=hf_quantizer,
#    4964         is_safetensors=is_offloaded_safetensors,
#    4965         keep_in_fp32_regex=keep_in_fp32_regex,
#    4966         unexpected_keys=unexpected_keys,
#    4967         device_mesh=device_mesh,
#    4968     )
#    4970 # force memory release if loading multiple shards, to avoid having 2 state dicts in memory in next loop
#    4971 del state_dict
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\modeling_utils.py:812, in _load_state_dict_into_meta_model(model, state_dict, shard_file, expected_keys, reverse_renaming_mapping, device_map, disk_offload_folder, disk_offload_index, cpu_offload_folder, cpu_offload_index, hf_quantizer, is_safetensors, keep_in_fp32_regex, unexpected_keys, device_mesh)
#     809     if is_fsdp_enabled():
#     810         param_device = "cpu" if is_local_dist_rank_0() else "meta"
# --> 812     _load_parameter_into_model(model, param_name, param.to(param_device))
#     814 else:
#     815     hf_quantizer.create_quantized_param(
#     816         model, param, param_name, param_device, state_dict, unexpected_keys
#     817     )
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\modeling_utils.py:700, in _load_parameter_into_model(model, param_name, tensor)
#     698 module, param_type = get_module_from_name(model, param_name)
#     699 # This will check potential shape mismatch if skipped before
# --> 700 module.load_state_dict({param_type: tensor}, strict=False, assign=True)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\nn\modules\module.py:2573, in Module.load_state_dict(self, state_dict, strict, assign)
#    2566         out = hook(module, incompatible_keys)
#    2567         assert out is None, (
#    2568             "Hooks registered with ``register_load_state_dict_post_hook`` are not"
#    2569             "expected to return new values, if incompatible_keys need to be modified,"
#    2570             "it should be done inplace."
#    2571         )
# -> 2573 load(self, state_dict)
#    2574 del load
#    2576 if strict:
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\nn\modules\module.py:2544, in Module.load_state_dict.<locals>.load(module, local_state_dict, prefix)
#    2542 if assign:
#    2543     local_metadata["assign_to_params_buffers"] = assign
# -> 2544 module._load_from_state_dict(
#    2545     local_state_dict,
#    2546     prefix,
#    2547     local_metadata,
#    2548     True,
#    2549     missing_keys,
#    2550     unexpected_keys,
#    2551     error_msgs,
#    2552 )
#    2553 for name, child in module._modules.items():
#    2554     if child is not None:
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\nn\modules\module.py:2350, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2314 r"""Copy parameters and buffers from :attr:`state_dict` into only this module, but not its descendants.
#    2315
#    2316 This is called on every submodule
#    (...)
#    2347         :meth:`~torch.nn.Module.load_state_dict`
#    2348 """
#    2349 for hook in self._load_state_dict_pre_hooks.values():
# -> 2350     hook(
#    2351         state_dict,
#    2352         prefix,
#    2353         local_metadata,
#    2354         strict,
#    2355         missing_keys,
#    2356         unexpected_keys,
#    2357         error_msgs,
#    2358     )
#    2360 persistent_buffers = {
#    2361     k: v
#    2362     for k, v in self._buffers.items()
#    2363     if k not in self._non_persistent_buffers_set
#    2364 }
#    2365 local_name_params = itertools.chain(
#    2366     self._parameters.items(), persistent_buffers.items()
#    2367 )
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\nn\modules\module.py:89, in _WrappedHook.__call__(self, *args, **kwargs)
#      87         raise RuntimeError("You are trying to call the hook of a dead Module!")
#      88     return self.hook(module, *args, **kwargs)
# ---> 89 return self.hook(*args, **kwargs)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\transformers\integrations\bitnet.py:270, in AutoBitLinear.load_hook(self, state_dict, prefix, *args, **kwargs)
#     262 def load_hook(
#     263     self,
#     264     state_dict,
#    (...)
#     267     **kwargs,
#     268 ):
#     269     if (prefix + "weight") in state_dict and state_dict[prefix + "weight"].dtype != self.weight.dtype:
# --> 270         state_dict[prefix + "weight"] = unpack_weights(state_dict[prefix + "weight"], dtype=self.weight.dtype)
#     271     return state_dict
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_dynamo\eval_frame.py:663, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     659     raise e.with_traceback(None) from None
#     660 except ShortenTraceback as e:
#     661     # Failures in the backend likely don't have useful
#     662     # data in the TorchDynamo frames, so we strip them out.
# --> 663     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#     664 finally:
#     665     # Restore the dynamic layer stack depth if necessary.
#     666     set_eval_frame(None)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\compile_fx.py:760, in _compile_fx_inner(gm, example_inputs, **graph_kwargs)
#     758     raise
#     759 except Exception as e:
# --> 760     raise InductorError(e, currentframe()).with_traceback(
#     761         e.__traceback__
#     762     ) from None
#     763 finally:
#     764     TritonBundler.end_compile()
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\compile_fx.py:745, in _compile_fx_inner(gm, example_inputs, **graph_kwargs)
#     743 TritonBundler.begin_compile()
#     744 try:
# --> 745     mb_compiled_graph = fx_codegen_and_compile(
#     746         gm, example_inputs, inputs_to_check, **graph_kwargs
#     747     )
#     748     assert mb_compiled_graph is not None
#     749     mb_compiled_graph._time_taken_ns = time.time_ns() - start_time
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\compile_fx.py:1295, in fx_codegen_and_compile(gm, example_inputs, inputs_to_check, **graph_kwargs)
#    1291     from .compile_fx_subproc import _SubprocessFxCompile
#    1293     scheme = _SubprocessFxCompile()
# -> 1295 return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\compile_fx.py:1197, in _InProcessFxCompile.codegen_and_compile(self, gm, example_inputs, inputs_to_check, graph_kwargs)
#    1184             compiled_fn = AotCodeCompiler.compile(
#    1185                 graph,
#    1186                 wrapper_code.value,
#    (...)
#    1194                 ],
#    1195             )
#    1196     else:
# -> 1197         compiled_fn = graph.compile_to_module().call
#    1199 num_bytes, nodes_num_elem, node_runtimes = graph.count_bytes()
#    1200 metrics.num_bytes_accessed += num_bytes
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\graph.py:2083, in GraphLowering.compile_to_module(self)
#    2076 def compile_to_module(self) -> ModuleType:
#    2077     with dynamo_timed(
#    2078         "GraphLowering.compile_to_module",
#    2079         phase_name="code_gen",
#    2080         log_pt2_compile_event=True,
#    2081         dynamo_compile_column_us="inductor_code_gen_cumulative_compile_time_us",
#    2082     ):
# -> 2083         return self._compile_to_module()
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\graph.py:2091, in GraphLowering._compile_to_module(self)
#    2086 from .codecache import PyCodeCache
#    2088 # Currently, if we're here, we don't have to worry about the kernel code, which
#    2089 # is only available in AOTInductor mode.
#    2090 wrapper_code, _ = (
# -> 2091     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
#    2092 )
#    2093 if config.triton.autotune_at_compile_time:
#    2094     tuning_code = (
#    2095         '"""\n'
#    2096         + "Compile-time auto-tuning block: \n"
#    (...)
#    2099         + '"""\n'
#    2100     )
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\graph.py:2002, in GraphLowering.codegen(self)
#    1999 V.debug.draw_orig_fx_graph(self.orig_gm, self.scheduler.nodes)
#    2001 self.wrapper_code.push_codegened_graph(self)
# -> 2002 self.scheduler.codegen()
#    2004 log.debug(
#    2005     "Finished codegen for all nodes. The list of kernel names available: %s",
#    2006     V.graph.all_codegen_kernel_names,
#    2007 )
#    2008 # Dump provenance artifacts for debugging trace
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\scheduler.py:4135, in Scheduler.codegen(self)
#    4130 def codegen(self) -> None:
#    4131     with dynamo_timed("Scheduler.codegen"):
#    4132         return (
#    4133             self._codegen_partitions()
#    4134             if torch._inductor.config.graph_partition
# -> 4135             else self._codegen(self.nodes)
#    4136         )
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\scheduler.py:4264, in Scheduler._codegen(self, nodes)
#    4262     backend.codegen_combo_kernel(node)
#    4263 elif isinstance(node, (FusedSchedulerNode, SchedulerNode)):
# -> 4264     self.get_backend(device).codegen_node(node)
#    4265 else:
#    4266     assert isinstance(node, NopKernelSchedulerNode)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\codegen\cpp.py:4986, in CppScheduling.codegen_node(self, node)
#    4984 nodes: list[SchedulerNode] = node.get_nodes()  # type: ignore[assignment]
#    4985 nodes = self.try_loop_split(nodes)
# -> 4986 cpp_kernel_proxy = CppKernelProxy(kernel_group)
#    4987 cpp_kernel_proxy.codegen_nodes(nodes)
#    4988 kernel_group.finalize_kernel(cpp_kernel_proxy, nodes)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\codegen\cpp.py:3734, in CppKernelProxy.__init__(self, kernel_group)
#    3732 self.loop_nest = None
#    3733 self.call_ranges = None
# -> 3734 self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
#    3735 self.kernels: list[CppKernel] = []
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:418, in pick_vec_isa()
#     415 if config.is_fbcode() and (platform.machine() in ["x86_64", "AMD64"]):
#     416     return VecAVX2()
# --> 418 _valid_vec_isa_list: list[VecISA] = valid_vec_isa_list()
#     419 if not _valid_vec_isa_list:
#     420     return invalid_vec_isa
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:405, in valid_vec_isa_list()
#     401     """
#     402     arch value is x86_64 on Linux, and the value is AMD64 on Windows.
#     403     """
#     404     _cpu_supported_x86_isa = x86_isa_checker()
# --> 405     isa_list.extend(
#     406         isa
#     407         for isa in supported_vec_isa_list
#     408         if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
#     409     )
#     411 return isa_list
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:408, in <genexpr>(.0)
#     401     """
#     402     arch value is x86_64 on Linux, and the value is AMD64 on Windows.
#     403     """
#     404     _cpu_supported_x86_isa = x86_isa_checker()
#     405     isa_list.extend(
#     406         isa
#     407         for isa in supported_vec_isa_list
# --> 408         if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa
#     409     )
#     411 return isa_list
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:142, in VecISA.__bool__(self)
#     141 def __bool__(self) -> bool:
# --> 142     return self.__bool__impl(config.cpp.vec_isa_ok)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:152, in VecISA.__bool__impl(self, vec_isa_ok)
#     149 if config.is_fbcode():
#     150     return True
# --> 152 return self.check_build(VecISA._avx_code)
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:102, in VecISA.check_build(self, code)
#      92 from torch._inductor.codecache import get_lock_dir, LOCK_TIMEOUT, write
#      93 from torch._inductor.cpp_builder import (
#      94     CppBuilder,
#      95     CppTorchOptions,
#      96     normalize_path_separator,
#      97 )
#      99 key, input_path = write(
#     100     code,
#     101     "cpp",
# --> 102     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
#     103 )
#     104 from torch.utils._filelock import FileLock
#     106 lock_dir = get_lock_dir()
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpu_vec_isa.py:28, in _get_isa_dry_compile_fingerprint(isa_flags)
#      19 def _get_isa_dry_compile_fingerprint(isa_flags: str) -> str:
#      20     # ISA dry compile will cost about 1 sec time each startup time.
#      21     # Please check the issue: https://github.com/pytorch/pytorch/issues/100378
#    (...)
#      24     # and generated them to output binary hash path.
#      25     # It would optimize and skip compile existing binary.
#      26     from torch._inductor.cpp_builder import get_compiler_version_info, get_cpp_compiler
# ---> 28     compiler_info = get_compiler_version_info(get_cpp_compiler())
#      29     torch_version = torch.__version__
#      30     fingerprint = f"{compiler_info}={isa_flags}={torch_version}"
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpp_builder.py:148, in get_cpp_compiler()
#     146 if _IS_WINDOWS:
#     147     compiler = os.environ.get("CXX", "cl")
# --> 148     check_compiler_exist_windows(compiler)
#     149 else:
#     150     if config.is_fbcode():
#
# File c:\Users\hyr69\anaconda3\envs\'genai'\Lib\site-packages\torch\_inductor\cpp_builder.py:139, in check_compiler_exist_windows(compiler)
#     137     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
#     138 except FileNotFoundError as exc:
# --> 139     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
#     140 except subprocess.SubprocessError:
#     141     # Expected that some compiler(clang, clang++) is exist, but they not support `/help` args.
#     142     pass
#
# InductorError: RuntimeError: Compiler: cl is not found.
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"
